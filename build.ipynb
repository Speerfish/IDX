# %% [markdown]
# # Build items with the Gemini API
#
# To get started, [get an API key](https://g.co/ai/idxGetGeminiKey) and replace the word `TODO` below with your API key:

# %%
API_KEY = 'AIzaSyCr8n7wa6y3aHRC7mofSyxIKUazrrmfgxE'

# %% [markdown]
# Once you're done, create a text prompt here:

# %%
prompt = 'Provide example building instructions for the items in the image'

# %% [markdown]
# And load an image with PIL:

# %%
import PIL.Image
# img = PIL.Image.open('brick-iron-gate.jpg')
img = PIL.Image.open('old-brick-house.jpg')
# img = PIL.Image.open('chicken-coop-1.jpg')
# img = PIL.Image.open('chicken-coop-2.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x1098>

# %% [markdown]
# And finally, call the Gemini API using the Python client library. [See the docs](https://developers.generativeai.google/guide)

# %%
import google.generativeai as genai
from IPython.display import Markdown, clear_output, display

genai.configure(api_key=API_KEY)

model = genai.GenerativeModel(model_name='gemini-1.5-flash')  # or gemini-1.5-pro
response = model.generate_content([prompt, img], stream=True)

buffer = []
for chunk in response:
    for part in chunk.parts:
        buffer.append(part.text)
    clear_output()
    display(Markdown(''.join(buffer)))
# Out:
# I am sorry, I cannot see or analyze any image. I am a text-based chat assistant and thus I cannot process any image.
